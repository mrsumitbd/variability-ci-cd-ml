# %%
import pandas as pd
import sys  
sys.path.insert(0, '../src/')
from process_github import *

# %%
df = pd.read_csv('../Relevant_Repos.csv')
df.head()
# Out:
#                                             RepoName BuildStatus  \
# 0  ahmad-abdellatif/3D-convolutional-speaker-reco...     errored
# 1           ahmad-abdellatif/abbreviation-extraction      passed
# 2                          ahmad-abdellatif/adam_qas     errored
# 3                              ahmad-abdellatif/ADNC     errored
# 4                             ahmad-abdellatif/agent     errored
#
#    TotalJobsRun  TotalPassedJobs
# 0           3.0              0.0
# 1           1.0              1.0
# 2           2.0              0.0
# 3           1.0              0.0
# 4           2.0              0.0

# %%
# NotThatAnonymous Token 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

# %%
passed_df = df.loc[df["BuildStatus"] == 'passed']

# %%
passed_df.head(100)
# Out:
#                                            RepoName BuildStatus  TotalJobsRun  \
# 1          ahmad-abdellatif/abbreviation-extraction      passed           1.0
# 5                          ahmad-abdellatif/AlphaPy      passed           2.0
# 11      ahmad-abdellatif/bad-commit-message-blocker      passed           1.0
# 21                           ahmad-abdellatif/choix      passed           1.0
# 30                           ahmad-abdellatif/delfi      passed           1.0
# 31                      ahmad-abdellatif/DenseTorch      passed           1.0
# 34                         ahmad-abdellatif/doc2vec      passed           1.0
# 38                          ahmad-abdellatif/Engine      passed           2.0
# 43                             ahmad-abdellatif/fer      passed           1.0
# 44                    ahmad-abdellatif/fishervector      passed           5.0
# 52                   ahmad-abdellatif/gluon2pytorch      passed           2.0
# ...

# %%
passed_df.shape
# Out:
# (40, 4)

# %%
dhia_df = pd.read_csv('../../Data/DhiaEtAl/Project_Set/ML/RQ2-DepthCorpusWithCurrentAdoption.csv')

# %%
dhia_df.head(3)
# Out:
#                              RepoName RepoType  \
# 0           duxuhao/Feature-Selection  Applied
# 1               kakaobrain/torchgpipe  Applied
# 2  ternaus/robot-surgery-segmentation  Applied
#
#                                            GitHubURL
# 0   https://github.com/duxuhao/Feature-Selection.git
# 1       https://github.com/kakaobrain/torchgpipe.git
# 2  https://github.com/ternaus/robot-surgery-segme...

# %%
process_GitHub = ProcessGitHub("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")

# %%
for repo in passed_df['RepoName'].tolist():
    print(repo)
    github_url = list(dhia_df.loc[dhia_df['RepoName'].str.contains(repo.split('/')[1]), 'RepoName'])[0]
    process_GitHub.create_fork(github_url)
# Out:
# ahmad-abdellatif/abbreviation-extraction
# ahmad-abdellatif/AlphaPy
# ahmad-abdellatif/bad-commit-message-blocker
# ahmad-abdellatif/choix
# ahmad-abdellatif/delfi
# ahmad-abdellatif/DenseTorch
# ahmad-abdellatif/doc2vec
# ahmad-abdellatif/Engine
# ahmad-abdellatif/fer
# ahmad-abdellatif/fishervector
# ahmad-abdellatif/gluon2pytorch
# ahmad-abdellatif/GOApy
# ahmad-abdellatif/kernel-gof
# ahmad-abdellatif/lagom
# ahmad-abdellatif/language-detector
# ahmad-abdellatif/light-weight-refinenet
# ahmad-abdellatif/MAX-Image-Resolution-Enhancer
# ahmad-abdellatif/MAX-Speech-to-Text-Converter
# ahmad-abdellatif/MAX-Weather-Forecaster
# ahmad-abdellatif/MLaaS4HEP
# ahmad-abdellatif/moe-serifu-agent
# ahmad-abdellatif/multi_rake
# ahmad-abdellatif/neuralcoref
# ahmad-abdellatif/pescador
# ahmad-abdellatif/PyKOMORAN
# ahmad-abdellatif/pyrrha-pynode
# ahmad-abdellatif/pywsd
# ahmad-abdellatif/recoder
# ahmad-abdellatif/rrcf
# ahmad-abdellatif/sacremoses
# ahmad-abdellatif/scattertext
# ...
